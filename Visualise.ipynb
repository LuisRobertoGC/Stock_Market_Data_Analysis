# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib notebook
from matplotlib import style
style.use('ggplot')

# %%
# %matplotlib notebook
def visualize_data():
    df = pd.read_csv('C:/Users/Desktop/Desktop/Dissertation/snp500/sp500_joined_closes.csv')
    df_corr = df.corr()
    print(df_corr.head())
    df_corr.to_csv('C:/Users/Desktop/Desktop/Dissertation/snp500/sp500corr.csv')
    data1 = df_corr.values
    fig1 = plt.figure()
    ax = fig1.add_subplot(1,1,1)

    heatmap = ax.pcolor(data1, cmap=plt.cm.RdYlGn)
    fig1.colorbar(heatmap)

    ax.set_xticks(np.arange(data1.shape[0]) + 0.5, minor=False)
    ax.set_yticks(np.arange(data1.shape[1]) + 0.5, minor=False)
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    
    column_labels = df_corr.columns
    row_labels = df_corr.index
    
    ax.set_xticklabels(column_labels)
    ax.set_yticklabels(row_labels)
    plt.xticks(rotation=90)
    heatmap.set_clim(-1, 1)
    plt.tight_layout()
    plt.show()

visualize_data()
# Out:
#            MMM       ABT      ABBV      ABMD       ACN      ATVI      ADBE  \
# MMM   1.000000  0.958215  0.928026  0.802376  0.978145  0.944940  0.899476
# ABT   0.958215  1.000000  0.922205  0.834649  0.977487  0.919468  0.911327
# ABBV  0.928026  0.922205  1.000000  0.891271  0.937858  0.912927  0.931890
# ABMD  0.802376  0.834649  0.891271  1.000000  0.868502  0.905241  0.969268
# ACN   0.978145  0.977487  0.937858  0.868502  1.000000  0.955120  0.931026
#
#            AMD       AAP       AES  ...      WLTW      WYNN       XEL  \
# MMM  -0.231127  0.863249 -0.231684  ...  0.941411  0.717318  0.967911
# ABT  -0.265155  0.879766 -0.192356  ...  0.904227  0.750825  0.963435
# ABBV  0.755133  0.202656  0.354859  ...  0.934375  0.214006  0.858709
# ABMD  0.093506  0.622425 -0.019431  ...  0.788408  0.486023  0.811957
# ACN  -0.102061  0.869504  0.105567  ...  0.927890  0.716071  0.982715
#
#            XRX      XLNX       XYL       YUM       ZBH      ZION       ZTS
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-352b09e4bc9c> in <module>
# ----> 1 import plotly.plotly as py
#       2 import plotly.graph_objs as go
#
# ~\anaconda3\envs\pvenv\lib\site-packages\plotly\plotly\__init__.py in <module>
#       2 from _plotly_future_ import _chart_studio_error
#       3
# ----> 4 _chart_studio_error("plotly")
#
# ~\anaconda3\envs\pvenv\lib\site-packages\_plotly_future_\__init__.py in _chart_studio_error(submodule)
#      47 chart_studio.{submodule} module instead.
#      48 """.format(
# ---> 49             submodule=submodule
#      50         )
#      51     )
#
# ImportError:
# The plotly.plotly module is deprecated,
# please install the chart-studio package and use the
# chart_studio.plotly module instead.

# %%
import plotly.express as px
#plotly.tools.set_credentials_file(username='Gauraz', api_key='j4TBAmq9UB7QcdWmF3hn')

# %%
df_market = pd.read_csv('C:/Users/Desktop/Desktop/Dissertation/snp500/MarketCap.csv')

# %%
labels = df_market['Ticker']
values = df_market['Market Cap']

# %%
trace = go.Pie(labels=labels, values=values)

# %%
py.iplot([trace], filename='MarketCap_piechart')
# Out:
# D:\Programs\Anaconda\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~gauraz.singh/1.embed" height="525px" width="100%"></iframe>
